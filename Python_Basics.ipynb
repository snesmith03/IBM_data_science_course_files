# %% [markdown]
# Python Basics - Basic Notes

# %%
# Highlights Python Basics including types, expressions, and strings 

# Source: IBM for Data Science 

'''
Python basics include data types, strings, and expressions in python 
Data types: int, float, str, boolean 
Some string methods: concatenation, split, upper, lower, find, replace
Expression = values + operations [(+), (-), (/), (//), (*)]
Indexing allow you to access certain elements or characters based on position
You can assign various variable names, but don't use the names of built in functions 

'''

# %% [markdown]
# Data Types

# %%
# Some of the most common data types are int, float, bool, and str
type('s') # str
# Out:
# str

# %%
type(123) # int
# Out:
# int

# %%
type(56.98) # float
# Out:
# float

# %%
type(True) # bool
# Out:
# bool

# %% [markdown]
# Strings

# %%
# The common string operations include concatenate, upper, lower, split, replace

# %%
# concatenate (add two strings together)
'''
str_1 = '11'
str_2 = '22'
combined_str = str_1 + str_2 
print(combined_str) # output should just combine all the numbers 
'''
# Another example:
# Key: When concatenating you yourself need to account for spacing (whitespace)
first = 'Mike'
last = 'Johnson'
print(first + " " + last)
# Out:
# Mike Johnson

# %% [markdown]
# Booleans

# %%
# bools are True or False ( 1 - True; 0 - False)
# you can turn boolean values into ints and floats 

int(True) # int
# float(True) # float 
# int(False) # int 
# float(False) # float
# Out:
# 1

# %% [markdown]
# Expressions

# %% [markdown]
# Extra - Regular Expression (re)
