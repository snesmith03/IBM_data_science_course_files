# %% [markdown]
# Mathematics

# %%
'''
Note: 
Python requires the import of the math library and then the use of math.function_name()

ex:
math.floor()
math.ceil()
math.sqrt()
math.factorial()
math.log()
'''

# %%
# use of sqrt example 
import math 
x = round(math.sqrt(27), 3)
print(x)
# Out:
# 5.196
