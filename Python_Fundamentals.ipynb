# %% [markdown]
# Conditioning & Branching

# %%
# conditioning relates to conditional operators (>, <, >=, <=, ==, !=)

i = 77
print(i <= 60 or i >= 55) # prints a boolean (False or True == True)
# Out:
# True

# %%
# branching focuses on if-else statements and if-elif-else statements
